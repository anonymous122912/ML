# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('agglomativeAlgoExcelFile.csv')
x = dataset.iloc[:,[1,2]].values

# %%
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt
dendrogram = sch.dendrogram(sch.linkage(x,method='ward'))
plt.title('Dendrogram')
plt.xlabel('attributes')
plt.ylabel('Euclidian Distance')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters=4, affinity=linkage='ward')
y_hc = hc.fit_predict(x)
y_hc
# Out:
# array([3, 3, 1, 0, 1, 0, 0, 2, 0, 2, 2], dtype=int64)

# %%
plt.scatter(x[y_hc==0,0], x[y_hc==0,1], s=100, c='red', label='Cluster-0')
plt.scatter(x[y_hc==1,0], x[y_hc==1,1], s=100, c='blue', label='Cluster-1')
plt.scatter(x[y_hc==2,0], x[y_hc==2,1], s=100, c='green', label='Cluster-2')
plt.scatter(x[y_hc==3,0], x[y_hc==3,1], s=100, c='yellow', label='Cluster-3')

# %%
plt.title('Scatter Diagram of Attributes')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
